# %%
cap.release()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %%
cap = cv2.VideoCapture(0)

while cap.isOpened():
  ret, frame = cap.read()
  cv2.imshow('0pen cv Feed', frame)
  if cv2.waitKey(10) & 0xFF == ord('q'):
    break
cap.release()
cv2.destroyAllWindows
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[57], line 5
#       3 while cap.isOpened():
#       4   ret, frame = cap.read()
# ----> 5   cv2.imshow('0pen cv Feed', frame)
#       6   if cv2.waitKey(10) & 0xFF == ord('q'):
#       7     break
#
# error: OpenCV(4.8.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/highgui/src/window.cpp:971: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'imshow'

# %%
mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
    image.flags.writeable = False                  
    results = model.process(image)                 
    image.flags.writeable = True                  
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) 
    return image, results

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        print(results)

        draw_styled_landmarks(image, results)


        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# /Users/my/myenv/lib/python3.11/site-packages/google/protobuf/symbol_database.py:78: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# 21

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) 
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

# %%
def draw_styled_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 

    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 

    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
frame
# Out:
# array([[[151, 184, 183],
#         [149, 182, 182],
#         [152, 184, 185],
#         ...,
#         [117, 140, 143],
#         [114, 139, 141],
#         [119, 145, 147]],
#
#        [[151, 184, 184],
#         [151, 183, 183],
#         [152, 182, 184],
#         ...,
#         [117, 140, 143],
#         [119, 143, 146],
#         [121, 147, 150]],
#
#        [[151, 183, 183],
#         [153, 184, 185],
#         [154, 182, 185],
#         ...,
#         [128, 150, 153],
#         [122, 147, 150],
#         [111, 138, 141]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 89, 119, 166],
#         [ 90, 120, 165],
#         [ 90, 118, 163]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 90, 121, 166],
#         [ 90, 120, 165],
#         [ 87, 116, 161]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [ 89, 120, 165],
#         [ 90, 120, 165],
#         [ 89, 118, 164]]], dtype=uint8)

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
DATA_PATH = os.path.join('MP_Data')


actions = np.array(['hello', 'thanks', 'iloveyou'])

# No. of videos(data)
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 for action in actions:
#       2     # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
#       3     for sequence in range(no_sequences):
#       4         try:
#
# NameError: name 'actions' is not defined

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.54642701,  0.69515908, -1.38619483, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    
    for action in actions:

        for sequence in range(no_sequences):

            for frame_num in range(sequence_length):

                ret, frame = cap.read()

                image, results = mediapipe_detection(frame, holistic)
                print(results)

                draw_styled_landmarks(image, results)
                
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)

                    cv2.imshow('OpenCV Feed', image)
                
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 26
#      22     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
#      23                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#      25     cv2.imshow('OpenCV Feed', image)
# ---> 26     cv2.waitKey(2000)
#      27 else:
#      28     cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12),
#      29                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
#
# KeyboardInterrupt:

# %%
cap.release()
cv2.destroyAllWindows()

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 label_map
#
# NameError: name 'label_map' is not defined

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 9
#       7     window.append(res)
#       8 sequences.append(window)
# ----> 9 labels.append(label_map[action])
#
# NameError: name 'label_map' is not defined

# %%
np.array(sequences).shape
# Out:
# (0,)

# %%
np.array(labels).shape
# Out:
# (0,)

# %%
X = np.array(sequences)

# %%
y = to_categorical(labels).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 y = to_categorical(labels).astype(int)
#
# NameError: name 'to_categorical' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
# Out:
# 2023-09-27 16:55:44.573562: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 6s 197ms/step - loss: 1.3596 - categorical_accuracy: 0.2706
# Epoch 2/2000
# 3/3 [==============================] - 0s 138ms/step - loss: 3.0645 - categorical_accuracy: 0.2941
# Epoch 3/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.0853 - categorical_accuracy: 0.4353
# Epoch 4/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.0969 - categorical_accuracy: 0.3529
# Epoch 5/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 1.0349 - categorical_accuracy: 0.4235
# Epoch 6/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.9618 - categorical_accuracy: 0.4588
# Epoch 7/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.9031 - categorical_accuracy: 0.6118
# Epoch 8/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 1.2298 - categorical_accuracy: 0.3647
# Epoch 9/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 1.2246 - categorical_accuracy: 0.3412
# Epoch 10/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.1267 - categorical_accuracy: 0.3412
# Epoch 11/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.0577 - categorical_accuracy: 0.5294
# Epoch 12/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.9845 - categorical_accuracy: 0.6235
# Epoch 13/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.8989 - categorical_accuracy: 0.6353
# Epoch 14/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.7181 - categorical_accuracy: 0.6353
# Epoch 15/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 1.0166 - categorical_accuracy: 0.6118
# Epoch 16/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7475 - categorical_accuracy: 0.6471
# Epoch 17/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.3630 - categorical_accuracy: 0.4353
# Epoch 18/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 1.1860 - categorical_accuracy: 0.3882
# Epoch 19/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.0307 - categorical_accuracy: 0.6471
# Epoch 20/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.9986 - categorical_accuracy: 0.5647
# Epoch 21/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.9700 - categorical_accuracy: 0.3765
# Epoch 22/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.9385 - categorical_accuracy: 0.3647
# Epoch 23/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.9017 - categorical_accuracy: 0.3647
# Epoch 24/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.8227 - categorical_accuracy: 0.4471
# Epoch 25/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.7717 - categorical_accuracy: 0.7176
# Epoch 26/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.6865 - categorical_accuracy: 0.6235
# Epoch 27/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.7356 - categorical_accuracy: 0.6353
# Epoch 28/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.8882 - categorical_accuracy: 0.5882
# Epoch 29/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.8327 - categorical_accuracy: 0.5647
# Epoch 30/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7996 - categorical_accuracy: 0.5882
# Epoch 31/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6884 - categorical_accuracy: 0.6941
# Epoch 32/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.7145 - categorical_accuracy: 0.6353
# Epoch 33/2000
# 3/3 [==============================] - 1s 141ms/step - loss: 0.6422 - categorical_accuracy: 0.7412
# Epoch 34/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6318 - categorical_accuracy: 0.5765
# Epoch 35/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6232 - categorical_accuracy: 0.5882
# Epoch 36/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.5950 - categorical_accuracy: 0.6235
# Epoch 37/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.5792 - categorical_accuracy: 0.6235
# Epoch 38/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.5534 - categorical_accuracy: 0.6471
# Epoch 39/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.4770 - categorical_accuracy: 0.7176
# Epoch 40/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4951 - categorical_accuracy: 0.8235
# Epoch 41/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.9096 - categorical_accuracy: 0.5882
# Epoch 42/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.8324 - categorical_accuracy: 0.5647
# Epoch 43/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.7209 - categorical_accuracy: 0.6118
# Epoch 44/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.6778 - categorical_accuracy: 0.6588
# Epoch 45/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.6873 - categorical_accuracy: 0.6588
# Epoch 46/2000
# 3/3 [==============================] - 0s 143ms/step - loss: 0.6822 - categorical_accuracy: 0.6706
# Epoch 47/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.6712 - categorical_accuracy: 0.6588
# Epoch 48/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.6739 - categorical_accuracy: 0.6706
# Epoch 49/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.6582 - categorical_accuracy: 0.8353
# Epoch 50/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.6361 - categorical_accuracy: 0.9647
# Epoch 51/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.6061 - categorical_accuracy: 0.9294
# Epoch 52/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.5672 - categorical_accuracy: 0.7765
# Epoch 53/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.5310 - categorical_accuracy: 0.8000
# Epoch 54/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.4535 - categorical_accuracy: 0.9176
# Epoch 55/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.5653 - categorical_accuracy: 0.8941
# Epoch 56/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.3252 - categorical_accuracy: 0.8824
# Epoch 57/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.4065 - categorical_accuracy: 0.8706
# Epoch 58/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7532 - categorical_accuracy: 0.7412
# Epoch 59/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 1.4788 - categorical_accuracy: 0.4824
# Epoch 60/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.6151 - categorical_accuracy: 0.6118
# Epoch 61/2000
# 3/3 [==============================] - 1s 226ms/step - loss: 0.6604 - categorical_accuracy: 0.5882
# Epoch 62/2000
# 3/3 [==============================] - 1s 206ms/step - loss: 0.6228 - categorical_accuracy: 0.6353
# Epoch 63/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.6131 - categorical_accuracy: 0.6471
# Epoch 64/2000
# 3/3 [==============================] - 0s 137ms/step - loss: 0.6158 - categorical_accuracy: 0.6471
# Epoch 65/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6345 - categorical_accuracy: 0.6471
# Epoch 66/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.5942 - categorical_accuracy: 0.6471
# Epoch 67/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.7119 - categorical_accuracy: 0.5647
# Epoch 68/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.6800 - categorical_accuracy: 0.5765
# Epoch 69/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.6029 - categorical_accuracy: 0.6353
# Epoch 70/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.5536 - categorical_accuracy: 0.6471
# Epoch 71/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.5424 - categorical_accuracy: 0.6471
# Epoch 72/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 0.6972 - categorical_accuracy: 0.6471
# Epoch 73/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.9502 - categorical_accuracy: 0.5412
# Epoch 74/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.3913 - categorical_accuracy: 0.3412
# Epoch 75/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 1.1810 - categorical_accuracy: 0.3412
# Epoch 76/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 1.1291 - categorical_accuracy: 0.3412
# Epoch 77/2000
# 3/3 [==============================] - 0s 145ms/step - loss: 1.1205 - categorical_accuracy: 0.3412
# Epoch 78/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.1171 - categorical_accuracy: 0.3412
# Epoch 79/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.1112 - categorical_accuracy: 0.3412
# Epoch 80/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 1.1084 - categorical_accuracy: 0.3412
# Epoch 81/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.1063 - categorical_accuracy: 0.3412
# Epoch 82/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.1043 - categorical_accuracy: 0.3412
# Epoch 83/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.1017 - categorical_accuracy: 0.3412
# Epoch 84/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.1000 - categorical_accuracy: 0.3412
# Epoch 85/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0983 - categorical_accuracy: 0.3412
# Epoch 86/2000
# 3/3 [==============================] - 0s 110ms/step - loss: 1.0971 - categorical_accuracy: 0.3412
# Epoch 87/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.0953 - categorical_accuracy: 0.3412
# Epoch 88/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0942 - categorical_accuracy: 0.3412
# Epoch 89/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 1.0925 - categorical_accuracy: 0.3412
# Epoch 90/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0908 - categorical_accuracy: 0.3412
# Epoch 91/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.0891 - categorical_accuracy: 0.3412
# Epoch 92/2000
# 3/3 [==============================] - 0s 180ms/step - loss: 1.0874 - categorical_accuracy: 0.3412
# Epoch 93/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0854 - categorical_accuracy: 0.3412
# Epoch 94/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0830 - categorical_accuracy: 0.3412
# Epoch 95/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 1.0803 - categorical_accuracy: 0.3412
# Epoch 96/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0771 - categorical_accuracy: 0.3412
# Epoch 97/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0736 - categorical_accuracy: 0.3412
# Epoch 98/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0689 - categorical_accuracy: 0.3412
# Epoch 99/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.0642 - categorical_accuracy: 0.3412
# Epoch 100/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.0568 - categorical_accuracy: 0.3412
# Epoch 101/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0474 - categorical_accuracy: 0.5412
# Epoch 102/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.0357 - categorical_accuracy: 0.6471
# Epoch 103/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.0170 - categorical_accuracy: 0.6588
# Epoch 104/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.9765 - categorical_accuracy: 0.6471
# Epoch 105/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.9176 - categorical_accuracy: 0.5765
# Epoch 106/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.0931 - categorical_accuracy: 0.3412
# Epoch 107/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.1053 - categorical_accuracy: 0.3412
# Epoch 108/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.1134 - categorical_accuracy: 0.3412
# Epoch 109/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 1.1100 - categorical_accuracy: 0.3412
# Epoch 110/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 1.1012 - categorical_accuracy: 0.3412
# Epoch 111/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 1.0880 - categorical_accuracy: 0.4118
# Epoch 112/2000
# 3/3 [==============================] - 1s 186ms/step - loss: 1.0687 - categorical_accuracy: 0.4471
# Epoch 113/2000
# 3/3 [==============================] - 1s 142ms/step - loss: 1.0413 - categorical_accuracy: 0.4588
# Epoch 114/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.9980 - categorical_accuracy: 0.4824
# Epoch 115/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.9541 - categorical_accuracy: 0.4118
# Epoch 116/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.8383 - categorical_accuracy: 0.6353
# Epoch 117/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.7570 - categorical_accuracy: 0.8706
# Epoch 118/2000
# 3/3 [==============================] - 1s 178ms/step - loss: 0.6417 - categorical_accuracy: 0.8118
# Epoch 119/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4739 - categorical_accuracy: 0.8941
# Epoch 120/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6596 - categorical_accuracy: 0.8353
# Epoch 121/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 5.5040 - categorical_accuracy: 0.4235
# Epoch 122/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 1.5180 - categorical_accuracy: 0.3412
# Epoch 123/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.2135 - categorical_accuracy: 0.3412
# Epoch 124/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 1.0515 - categorical_accuracy: 0.3765
# Epoch 125/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.9548 - categorical_accuracy: 0.6706
# Epoch 126/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.8914 - categorical_accuracy: 0.5765
# Epoch 127/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.8771 - categorical_accuracy: 0.5412
# Epoch 128/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 0.8184 - categorical_accuracy: 0.7765
# Epoch 129/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7877 - categorical_accuracy: 0.9059
# Epoch 130/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.7722 - categorical_accuracy: 0.8353
# Epoch 131/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7201 - categorical_accuracy: 0.9529
# Epoch 132/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.6518 - categorical_accuracy: 0.9412
# Epoch 133/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.6153 - categorical_accuracy: 0.8588
# Epoch 134/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.5072 - categorical_accuracy: 0.9765
# Epoch 135/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.3813 - categorical_accuracy: 0.9765
# Epoch 136/2000
# 3/3 [==============================] - 0s 148ms/step - loss: 0.3992 - categorical_accuracy: 0.8706
# Epoch 137/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4234 - categorical_accuracy: 0.8471
# Epoch 138/2000
# 3/3 [==============================] - 0s 170ms/step - loss: 0.5541 - categorical_accuracy: 0.7647
# Epoch 139/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 0.5658 - categorical_accuracy: 0.6118
# Epoch 140/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.4689 - categorical_accuracy: 0.8118
# Epoch 141/2000
# 3/3 [==============================] - 0s 142ms/step - loss: 0.4466 - categorical_accuracy: 0.7529
# Epoch 142/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.3996 - categorical_accuracy: 0.9176
# Epoch 143/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.3111 - categorical_accuracy: 0.9412
# Epoch 144/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.2337 - categorical_accuracy: 0.9765
# Epoch 145/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.2274 - categorical_accuracy: 0.9647
# Epoch 146/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.3584 - categorical_accuracy: 0.8941
# Epoch 147/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 3.0127 - categorical_accuracy: 0.3294
# Epoch 148/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.9502 - categorical_accuracy: 0.5647
# Epoch 149/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.1426 - categorical_accuracy: 0.3294
# Epoch 150/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.7536 - categorical_accuracy: 0.7294
# Epoch 151/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6994 - categorical_accuracy: 0.7412
# Epoch 152/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6593 - categorical_accuracy: 0.7412
# Epoch 153/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.6399 - categorical_accuracy: 0.9647
# Epoch 154/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.6788 - categorical_accuracy: 0.9059
# Epoch 155/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.5999 - categorical_accuracy: 0.9647
# Epoch 156/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.5917 - categorical_accuracy: 0.8824
# Epoch 157/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.5529 - categorical_accuracy: 0.9294
# Epoch 158/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.5161 - categorical_accuracy: 0.9647
# Epoch 159/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.5027 - categorical_accuracy: 0.9647
# Epoch 160/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.4601 - categorical_accuracy: 0.9647
# Epoch 161/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.4373 - categorical_accuracy: 0.9529
# Epoch 162/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.4106 - categorical_accuracy: 0.9647
# Epoch 163/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.3780 - categorical_accuracy: 0.9647
# Epoch 164/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.3501 - categorical_accuracy: 0.9765
# Epoch 165/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.3162 - categorical_accuracy: 0.9765
# Epoch 166/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.2802 - categorical_accuracy: 0.9765
# Epoch 167/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.2378 - categorical_accuracy: 0.9765
# Epoch 168/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.1952 - categorical_accuracy: 0.9882
# Epoch 169/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1608 - categorical_accuracy: 0.9765
# Epoch 170/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 0.1446 - categorical_accuracy: 0.9882
# Epoch 171/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.1342 - categorical_accuracy: 0.9765
# Epoch 172/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.1128 - categorical_accuracy: 0.9882
# Epoch 173/2000
# 3/3 [==============================] - 1s 139ms/step - loss: 0.1071 - categorical_accuracy: 0.9882
# Epoch 174/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0801 - categorical_accuracy: 0.9882
# Epoch 175/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1027 - categorical_accuracy: 0.9765
# Epoch 176/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0635 - categorical_accuracy: 0.9765
# Epoch 177/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0698 - categorical_accuracy: 0.9882
# Epoch 178/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0778 - categorical_accuracy: 0.9882
# Epoch 179/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0627 - categorical_accuracy: 0.9765
# Epoch 180/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0818 - categorical_accuracy: 0.9647
# Epoch 181/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.0579 - categorical_accuracy: 0.9882
# Epoch 182/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0908 - categorical_accuracy: 0.9647
# Epoch 183/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0634 - categorical_accuracy: 0.9882
# Epoch 184/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0475 - categorical_accuracy: 0.9882
# Epoch 185/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0410 - categorical_accuracy: 0.9765
# Epoch 186/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0316 - categorical_accuracy: 0.9882
# Epoch 187/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0230 - categorical_accuracy: 0.9882
# Epoch 188/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0236 - categorical_accuracy: 0.9882
# Epoch 189/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0326 - categorical_accuracy: 0.9882
# Epoch 190/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0403 - categorical_accuracy: 0.9882
# Epoch 191/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0375 - categorical_accuracy: 0.9882
# Epoch 192/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0210 - categorical_accuracy: 0.9882
# Epoch 193/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0242 - categorical_accuracy: 1.0000
# Epoch 194/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0208 - categorical_accuracy: 0.9882
# Epoch 195/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0177 - categorical_accuracy: 0.9882
# Epoch 196/2000
# 3/3 [==============================] - 0s 134ms/step - loss: 0.0154 - categorical_accuracy: 1.0000
# Epoch 197/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0092 - categorical_accuracy: 1.0000
# Epoch 198/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0070 - categorical_accuracy: 1.0000
# Epoch 199/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0086 - categorical_accuracy: 1.0000
# Epoch 200/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0099 - categorical_accuracy: 1.0000
# Epoch 201/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0043 - categorical_accuracy: 1.0000
# Epoch 202/2000
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0146 - categorical_accuracy: 0.9882
# Epoch 203/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0215 - categorical_accuracy: 1.0000
# Epoch 204/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0361 - categorical_accuracy: 0.9882
# Epoch 205/2000
# 3/3 [==============================] - 1s 121ms/step - loss: 0.0224 - categorical_accuracy: 0.9882
# Epoch 206/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0050 - categorical_accuracy: 1.0000
# Epoch 207/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0418 - categorical_accuracy: 0.9882
# Epoch 208/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0927 - categorical_accuracy: 0.9882
# Epoch 209/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0629 - categorical_accuracy: 0.9765
# Epoch 210/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1014 - categorical_accuracy: 0.9765
# Epoch 211/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.1282 - categorical_accuracy: 0.9294
# Epoch 212/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.1633 - categorical_accuracy: 0.9059
# Epoch 213/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.1614 - categorical_accuracy: 0.9765
# Epoch 214/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.1671 - categorical_accuracy: 0.9765
# Epoch 215/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1407 - categorical_accuracy: 0.9647
# Epoch 216/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 0.0954 - categorical_accuracy: 0.9882
# Epoch 217/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0644 - categorical_accuracy: 0.9882
# Epoch 218/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0453 - categorical_accuracy: 0.9882
# Epoch 219/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0495 - categorical_accuracy: 0.9882
# Epoch 220/2000
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0562 - categorical_accuracy: 0.9765
# Epoch 221/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0674 - categorical_accuracy: 0.9765
# Epoch 222/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0272 - categorical_accuracy: 0.9882
# Epoch 223/2000
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0826 - categorical_accuracy: 0.9765
# Epoch 224/2000
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0598 - categorical_accuracy: 0.9647
# Epoch 225/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0358 - categorical_accuracy: 0.9882
# Epoch 226/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0545 - categorical_accuracy: 0.9882
# Epoch 227/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0296 - categorical_accuracy: 1.0000
# Epoch 228/2000
# 3/3 [==============================] - 0s 135ms/step - loss: 0.0320 - categorical_accuracy: 0.9882
# Epoch 229/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0229 - categorical_accuracy: 0.9882
# Epoch 230/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0243 - categorical_accuracy: 0.9882
# Epoch 231/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0161 - categorical_accuracy: 0.9882
# Epoch 232/2000
# 3/3 [==============================] - 0s 112ms/step - loss: 0.0143 - categorical_accuracy: 1.0000
# Epoch 233/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0096 - categorical_accuracy: 1.0000
# Epoch 234/2000
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0147 - categorical_accuracy: 0.9882
# Epoch 235/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0081 - categorical_accuracy: 1.0000
# Epoch 236/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0103 - categorical_accuracy: 1.0000
# Epoch 237/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 238/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0060 - categorical_accuracy: 1.0000
# Epoch 239/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0068 - categorical_accuracy: 1.0000
# Epoch 240/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0063 - categorical_accuracy: 1.0000
# Epoch 241/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0083 - categorical_accuracy: 1.0000
# Epoch 242/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 0.0033 - categorical_accuracy: 1.0000
# Epoch 243/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 0.0083 - categorical_accuracy: 1.0000
# Epoch 244/2000
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0037 - categorical_accuracy: 1.0000
# Epoch 245/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0067 - categorical_accuracy: 1.0000
# Epoch 246/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0036 - categorical_accuracy: 1.0000
# Epoch 247/2000
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0051 - categorical_accuracy: 1.0000
# Epoch 248/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 249/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0032 - categorical_accuracy: 1.0000
# Epoch 250/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0052 - categorical_accuracy: 1.0000
# Epoch 251/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0054 - categorical_accuracy: 1.0000
# Epoch 252/2000
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0038 - categorical_accuracy: 1.0000
# Epoch 253/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 254/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 0.0042 - categorical_accuracy: 1.0000
# Epoch 255/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 0.0018 - categorical_accuracy: 1.0000
# Epoch 256/2000
# 3/3 [==============================] - 0s 140ms/step - loss: 0.0096 - categorical_accuracy: 0.9882
# Epoch 257/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0074 - categorical_accuracy: 1.0000
# Epoch 258/2000
# 3/3 [==============================] - 0s 114ms/step - loss: 0.0034 - categorical_accuracy: 1.0000
# Epoch 259/2000
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0016 - categorical_accuracy: 1.0000
# Epoch 260/2000
# 3/3 [==============================] - 1s 199ms/step - loss: 0.0057 - categorical_accuracy: 1.0000
# Epoch 261/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 0.0019 - categorical_accuracy: 1.0000
# Epoch 262/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 0.0017 - categorical_accuracy: 1.0000
# Epoch 263/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0021 - categorical_accuracy: 1.0000
# Epoch 264/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 0.0012 - categorical_accuracy: 1.0000
# Epoch 265/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 9.1369e-04 - categorical_accuracy: 1.0000
# Epoch 266/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 9.3722e-04 - categorical_accuracy: 1.0000
# Epoch 267/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 9.8150e-04 - categorical_accuracy: 1.0000
# Epoch 268/2000
# 3/3 [==============================] - 0s 136ms/step - loss: 7.7434e-04 - categorical_accuracy: 1.0000
# Epoch 269/2000
# 3/3 [==============================] - 0s 122ms/step - loss:
2000
# 3/3 [==============================] - 0s 119ms/step - loss: 2.4658e-04 - categorical_accuracy: 1.0000
# Epoch 299/2000
# 3/3 [==============================] - 0s 132ms/step - loss: 2.3765e-04 - categorical_accuracy: 1.0000
# Epoch 300/2000
# 3/3 [==============================] - 0s 130ms/step - loss: 2.3573e-04 - categorical_accuracy: 1.0000
# Epoch 301/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 2.2755e-04 - categorical_accuracy: 1.0000
# Epoch 302/2000
# 3/3 [==============================] - 1s 154ms/step - loss: 2.1957e-04 - categorical_accuracy: 1.0000
# Epoch 303/2000
# 3/3 [==============================] - 0s 125ms/step - loss: 2.1878e-04 - categorical_accuracy: 1.0000
# Epoch 304/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 2.0916e-04 - categorical_accuracy: 1.0000
# Epoch 305/2000
# 3/3 [==============================] - 0s 127ms/step - loss: 2.0129e-04 - categorical_accuracy: 1.0000
# Epoch 306/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.9998e-04 - categorical_accuracy: 1.0000
# Epoch 307/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 1.9472e-04 - categorical_accuracy: 1.0000
# Epoch 308/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 1.8904e-04 - categorical_accuracy: 1.0000
# Epoch 309/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.8233e-04 - categorical_accuracy: 1.0000
# Epoch 310/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.7892e-04 - categorical_accuracy: 1.0000
# Epoch 311/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.7409e-04 - categorical_accuracy: 1.0000
# Epoch 312/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.6982e-04 - categorical_accuracy: 1.0000
# Epoch 313/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 1.6467e-04 - categorical_accuracy: 1.0000
# Epoch 314/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.6175e-04 - categorical_accuracy: 1.0000
# Epoch 315/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.5763e-04 - categorical_accuracy: 1.0000
# Epoch 316/2000
# 3/3 [==============================] - 0s 161ms/step - loss: 1.5453e-04 - categorical_accuracy: 1.0000
# Epoch 317/2000
# 3/3 [==============================] - 0s 131ms/step - loss: 1.5249e-04 - categorical_accuracy: 1.0000
# Epoch 318/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 1.4777e-04 - categorical_accuracy: 1.0000
# Epoch 319/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 1.4523e-04 - categorical_accuracy: 1.0000
# Epoch 320/2000
# 3/3 [==============================] - 0s 126ms/step - loss: 1.4158e-04 - categorical_accuracy: 1.0000
# Epoch 321/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.3864e-04 - categorical_accuracy: 1.0000
# Epoch 322/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 1.3502e-04 - categorical_accuracy: 1.0000
# Epoch 323/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.3297e-04 - categorical_accuracy: 1.0000
# Epoch 324/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 1.2998e-04 - categorical_accuracy: 1.0000
# Epoch 325/2000
# 3/3 [==============================] - 0s 115ms/step - loss: 1.2682e-04 - categorical_accuracy: 1.0000
# Epoch 326/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.2481e-04 - categorical_accuracy: 1.0000
# Epoch 327/2000
# 3/3 [==============================] - 0s 122ms/step - loss: 1.2269e-04 - categorical_accuracy: 1.0000
# Epoch 328/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 1.2114e-04 - categorical_accuracy: 1.0000
# Epoch 329/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 1.1806e-04 - categorical_accuracy: 1.0000
# Epoch 330/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 1.1448e-04 - categorical_accuracy: 1.0000
# Epoch 331/2000
# 3/3 [==============================] - 0s 121ms/step - loss:
2000
# 3/3 [==============================] - 0s 122ms/step - loss: 4.5509e-05 - categorical_accuracy: 1.0000
# Epoch 393/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 4.4811e-05 - categorical_accuracy: 1.0000
# Epoch 394/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 4.4537e-05 - categorical_accuracy: 1.0000
# Epoch 395/2000
# 3/3 [==============================] - 0s 120ms/step - loss: 4.3728e-05 - categorical_accuracy: 1.0000
# Epoch 396/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 4.3305e-05 - categorical_accuracy: 1.0000
# Epoch 397/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 4.2698e-05 - categorical_accuracy: 1.0000
# Epoch 398/2000
# 3/3 [==============================] - 0s 116ms/step - loss: 4.2230e-05 - categorical_accuracy: 1.0000
# Epoch 399/2000
# 3/3 [==============================] - 1s 201ms/step - loss: 4.1840e-05 - categorical_accuracy: 1.0000
# Epoch 400/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 4.1404e-05 - categorical_accuracy: 1.0000
# Epoch 401/2000
# 3/3 [==============================] - 0s 119ms/step - loss: 4.0905e-05 - categorical_accuracy: 1.0000
# Epoch 402/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 4.0376e-05 - categorical_accuracy: 1.0000
# Epoch 403/2000
# 3/3 [==============================] - 0s 139ms/step - loss: 3.9864e-05 - categorical_accuracy: 1.0000
# Epoch 404/2000
# 3/3 [==============================] - 0s 147ms/step - loss: 3.9468e-05 - categorical_accuracy: 1.0000
# Epoch 405/2000
# 3/3 [==============================] - 0s 128ms/step - loss: 3.9278e-05 - categorical_accuracy: 1.0000
# Epoch 406/2000
# 3/3 [==============================] - 0s 141ms/step - loss: 3.8803e-05 - categorical_accuracy: 1.0000
# Epoch 407/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.8325e-05 - categorical_accuracy: 1.0000
# Epoch 408/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 3.7836e-05 - categorical_accuracy: 1.0000
# Epoch 409/2000
# 3/3 [==============================] - 0s 117ms/step - loss: 3.7453e-05 - categorical_accuracy: 1.0000
# Epoch 410/2000
# 3/3 [==============================] - 0s 121ms/step - loss: 3.7054e-05 - categorical_accuracy: 1.0000
# Epoch 411/2000
# 3/3 [==============================] - 0s 118ms/step - loss: 3.6888e-05 - categorical_accuracy: 1.0000
# Epoch 412/2000
# 3/3 [==============================] - 1s 185ms/step - loss: 3.6212e-05 - categorical_accuracy: 1.0000
# Epoch 413/2000
# 3/3 [==============================] - 0s 123ms/step - loss: 3.5975e-05 - categorical_accuracy: 1.0000
# Epoch 414/2000
# 3/3 [==============================] - 0s 151ms/step - loss: 3.5518e-05 - categorical_accuracy: 1.0000
# Epoch 415/2000
# 3/3 [==============================] - 0s 124ms/step - loss: 3.5071e-05 - categorical_accuracy: 1.0000
# Epoch 416/2000
# 3/3 [==============================] - 1s 200ms/step - loss: 3.4586e-05 - categorical_accuracy: 1.0000
# Epoch 417/2000
# ...
# Epoch 1343/2000
# 3/3 [==============================] - 1s 204ms/step - loss: 4.0251e-07 - categorical_accuracy: 1.0000
# Epoch 1344/2000
# 3/3 [==============================] - 1s 189ms/step - loss: 4.0110e-07 - categorical_accuracy: 1.0000
# Epoch 1345/2000
# 3/3 [==============================] - 1s 179ms/step - loss: 4.0110e-07 - categorical_accuracy: 1.0000
# Epoch 1346/2000
# 3/3 [==============================] - 1s 196ms/step - loss: 4.0110e-07 - categorical_accuracy: 1.0000
# Epoch 1347/2000
# 3/3 [==============================] - 0s 149ms/step - loss: 4.0110e-07 - categorical_accuracy: 1.0000
# Epoch 1348/2000
# Epoch 1423/2000
# 3/3 [==============================] - 0s 146ms/step - loss: 3.3238e-07 - categorical_accuracy: 1.0000
# Epoch 1424/2000
# 3/3 [==============================] - 0s 162ms/step - loss: 3.3238e-07 - categorical_accuracy: 1.0000
# Epoch 1425/2000
# 3/3 [==============================] - 0s 159ms/step - loss: 3.3098e-07 - categorical_accuracy: 1.0000
# Epoch 1426/2000
# 3/3 [==============================] - 1s 165ms/step - loss: 3.2537e-07 - categorical_accuracy: 1.0000
# Epoch 1427/2000
# 3/3 [==============================] - 0s 144ms/step - loss: 3.2537e-07 - categorical_accuracy: 1.0000
# Epoch 1428/2000
# 3/3 [==============================] - 0s 156ms/step - loss: 3.2397e-07 - categorical_accuracy: 1.0000
# Epoch 1429/2000
# 2/3 [===================>..........] - ETA: 0s - loss: 2.0489e-07 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File ~/myenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/myenv/lib/python3.11/site-packages/keras/src/engine/training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:194, in AtomicFunction.__call__(self, *args)
#     187 with _InterpolateFunctionError(self):
#     188   with ops.control_dependencies(self._graph_artifacts.control_captures):
#     189     # The caller must use record_operation to record this operation in the
#     190     # eager case, so we enforce the same requirement for the non-eager
#     191     # case by explicitly pausing recording. We don't have a gradient
#     192     # registered for PartitionedCall, so recording this operation confuses
#     193     # forwardprop code (GradientTape manages to ignore it).
# --> 194     with record.stop_recording():
#     195       if self._bound_context.executing_eagerly():
#     196         outputs = self._bound_context.call_function(
#     197             self.name,
#     198             list(args),
#     199             len(self.function_type.flat_outputs),
#     200         )
#
# File /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/myenv/lib/python3.11/site-packages/tensorflow/python/eager/record.py:54, in stop_recording()
#      49     """Returns a tuple of variables accessed under this scope."""
#      50     return pywrap_tfe.TFE_Py_VariableWatcherWatchedVariables(
#      51         self._variable_watcher)
# ---> 54 @contextlib.contextmanager
#      55 def stop_recording():
#      56   """Stop all gradient recording (backprop and forwardprop)."""
#      57   is_stopped = pywrap_tfe.TFE_Py_TapeSetIsStopped()
#
# KeyboardInterrupt:

# %%
# !python3 -m tensorboard.main --logdir=/Users/my/Desktop/Action_Detection/Logs/train
# Out:
# 2023-09-25 16:15:39.024504: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.13.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
res = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 res = model.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
actions[np.argmax(res[2])]
# Out:
# 'iloveyou'

# %%
actions[np.argmax(y_test[2])]
# Out:
# 'iloveyou'

# %%
model.save('actdect.h5')

# %%
del model

# %%
model.load_weights('actdect.h5')

# %%
model.load_weights('action.h5')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30, 64)            442112
#
#  lstm_4 (LSTM)               (None, 30, 128)           98816
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 596675 (2.28 MB)
# Trainable params: 596675 (2.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
# yhat = model.predict(X_test)
yhat = model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # yhat = model.predict(X_test)
# ----> 2 yhat = model.predict(X_train)
#
# NameError: name 'X_train' is not defined

# %%
# ytrue = np.argmax(y_test, axis=1).tolist()
# yhat = np.argmax(yhat, axis=1).tolist()

ytrue = np.argmax(y_train, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[59,  0],
#         [ 0, 26]],
#
#        [[55,  0],
#         [ 0, 30]],
#
#        [[56,  0],
#         [ 0, 29]]])

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))

# %%
sequence = []
sentence = []
predictions = []
threshold = 0.6

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        ret, frame = cap.read()

        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        draw_styled_landmarks(image, results)
        
        keypoints = extract_keypoints(results)

        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            if np.unique(predictions[-10:])[0]==np.argmax(res):
                if res[np.argmax(res)] > threshold: 
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            image = prob_viz(res, actions, image, colors)


            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# /Users/my/myenv/lib/python3.11/site-packages/google/protobuf/symbol_database.py:78: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 1s 1s/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 46ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 57ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 41ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 28ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 38ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 37ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 42ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 29ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 39ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 36ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 43ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 33ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 30ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 40ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 34ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 35ms/step
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 [==============================] - 0s 51ms/step
# iloveyou
